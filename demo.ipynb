# %%
store = {'my_msg': 'hello world'}

print('my_msg' in store)
# Out:
# True

# %%
# 查看当前可用的搜索工具
from langchain_community.tools import __all__ as all_tools
print("可用的搜索工具:", [t for t in all_tools if 'search' in t.lower()])

"""
可用的搜索工具: ['AskNewsSearch', 'BingSearchResults', 'BingSearchRun', 'BraveSearch', 'DuckDuckGoSearchResults', 'DuckDuckGoSearchRun', 'FileSearchTool', 'GmailSearch', 'GoogleSearchResults', 'GoogleSearchRun', 'JinaSearch', 'MetaphorSearchResults', 'MojeekSearch', 'O365SearchEmails', 'O365SearchEvents', 'RedditSearchRun', 'RedditSearchSchema', 'SearchAPIResults', 'SearchAPIRun', 'SearxSearchResults', 'SearxSearchRun', 'TavilySearchResults', 'YouSearchTool', 'YouTubeSearchTool']


可用的搜索工具分析

从你的输出中，这些工具特别值得关注：

免费工具（无需 API Key）：

python
# 1. DuckDuckGo - 你现在用的
from langchain_community.tools import DuckDuckGoSearchRun

# 2. Searx - 开源元搜索引擎
from langchain_community.tools import SearxSearchRun


python
# 需要对应平台的 API Key
from langchain_community.tools import (
    GoogleSearchRun,      # Google Search API
    BingSearchRun,        # Bing Search API  
    BraveSearch,          # Brave Search API
    TavilySearchResults,  # Tavily API
    YouSearchTool,        # You.com API
    JinaSearch,           # Jina AI Search
    Mojeek
)
"""
# Out:
# 可用的搜索工具: ['AskNewsSearch', 'BingSearchResults', 'BingSearchRun', 'BraveSearch', 'DuckDuckGoSearchResults', 'DuckDuckGoSearchRun', 'FileSearchTool', 'GmailSearch', 'GoogleSearchResults', 'GoogleSearchRun', 'JinaSearch', 'MetaphorSearchResults', 'MojeekSearch', 'O365SearchEmails', 'O365SearchEvents', 'RedditSearchRun', 'RedditSearchSchema', 'SearchAPIResults', 'SearchAPIRun', 'SearxSearchResults', 'SearxSearchRun', 'TavilySearchResults', 'YouSearchTool', 'YouTubeSearchTool']
